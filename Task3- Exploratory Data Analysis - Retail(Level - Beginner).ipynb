# %% [markdown]
# # <font color='blue'>DATA SCIENCE AND BUSINESS ANALYTICS INTERNSHIP @GRIP THE Spark Foundation</font>
#
# Task3:-Exploratory Data Analysis - Retail(Level - Beginner)
#
# Author: Anuradha Kumari
#
# Important Points Evaluated in Task:
#
# <strong> Problem Statement- As a business manager, try to find out the weak areas where you can work to make more profit.</strong>
#
# 1.Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# 2.All business problems you can derive by exploring the data
#
# 3.Data Set:https://bit.ly/3i4rbWl
#
# ## Exploratory Data Analysis
# Exploratory data analysis is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods. Here in our task we will Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’ and try to find out the weak areas where we can work to make more profit. As a business manager we have to solve this problem. We will analyse and solve this problem and explore for other business problems as well.

# %% [markdown]
# # Importing All the Required Libraries in Task

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
EDA_df = pd.read_csv('SampleSuperstore.csv')

# %%
EDA_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
EDA_df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
EDA_df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
EDA_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
EDA_df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
EDA_df.shape
# Out:
# (9994, 13)

# %%
#Check Null values
EDA_df.isnull().any()
# Out:
# Ship Mode       False
# Segment         False
# Country         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %%
#Droping Columns:
#Country: Its value is same through out the column
#Postal Code: Its changing its value with city so can use city instead of it
EDA_df.drop(['Country','Postal Code'], axis=1,inplace=True)

# %% [markdown]
# # Data visualization

# %% [markdown]
# ### Shipment Mode

# %%
print("Most Shiping method:",EDA_df['Ship Mode'].value_counts().idxmax())
EDA_df['Ship Mode'].value_counts()
# Out:
# Most Shiping method: Standard Class
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(EDA_df['Ship Mode'])
plt.title('Ship Mode',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Ship Mode')

# %%
EDA_df.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                      Sales  Discount     Profit
# Ship Mode
# First Class     228.497024  0.164610  31.839948
# Same Day        236.396179  0.152394  29.266591
# Second Class    236.089239  0.138895  29.535545
# Standard Class  227.583067  0.160023  27.494770

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Profit and Discount is high in First Class.
#
# -Sales is high for Same day ship.

# %% [markdown]
# ### Segment

# %%
print("Segment with maximum Sales count:",EDA_df['Segment'].value_counts().idxmax())
EDA_df['Segment'].value_counts()
# Out:
# Segment with maximum Sales count: Consumer
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(EDA_df['Segment'])
plt.title('Segment',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Segment')

# %%
EDA_df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Profit and Sales is high in Home Office.
#
# -Sales deals is high for Consumer Segment.

# %% [markdown]
# ### Region

# %%
print("Region with maximum Sales count:",EDA_df['Region'].value_counts().idxmax())
EDA_df['Region'].value_counts()
# Out:
# Region with maximum Sales count: West
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(EDA_df['Region'])
plt.title('Region',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Region')

# %%
EDA_df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Sales is highest in East Region.
#
# -Sales deals & Profit is highest in West Region.

# %% [markdown]
# ### Category

# %%
print("Category with maximum Sales count:",EDA_df['Category'].value_counts().idxmax())
EDA_df['Category'].value_counts()
# Out:
# Category with maximum Sales count: Office Supplies
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(EDA_df['Category'])
plt.title('Category',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Category')

# %%
EDA_df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Maximun sales and Profit obtain in Technology.
#
# -Minimun profit obtain in Furniture
#
# -Sales deals is highest in Office Supplies.

# %% [markdown]
# ### Sub-Category

# %%
print("Sub-Category with maximum Sales count: {} & with minimum Sales count: {}".format(EDA_df['Sub-Category'].value_counts().idxmax(),EDA_df['Sub-Category'].value_counts().idxmin()))
EDA_df['Sub-Category'].value_counts().head(5)
# Out:
# Sub-Category with maximum Sales count: Binders & with minimum Sales count: Copiers
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(EDA_df['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %%
EDA_df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918
# Labels          34.303055  0.068681   15.236962
# Machines      1645.553313  0.306087   29.432669
# Paper           57.284092  0.074891   24.856620
# Phones         371.211534  0.154556   50.073938
# Storage        264.590553  0.074704   25.152277
# Supplies       245.650200  0.076842   -6.258418
# Tables         648.794771  0.261285  -55.565771

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Copier: High Profit & sales.
#
# -Binders , Machines and then tables have high Discount
#
# -Sales deals is highest in Binders.

# %% [markdown]
# ### State

# %%
print("State with maximum Sales count: {} & with minimum Sales count: {}".format(EDA_df['State'].value_counts().idxmax(),EDA_df['State'].value_counts().idxmin()))
EDA_df['State'].value_counts().head(5)
# Out:
# State with maximum Sales count: California & with minimum Sales count: Wyoming
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: State, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(EDA_df['State'])
plt.xticks(rotation = 35)
plt.title('State',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State')

# %%
x=EDA_df.groupby(by="State")[['Profit']].sum()
b=x.sort_values(by=['Profit'],ascending=True)
b.plot(kind='bar')
plt.show()

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Here is top 3 state where deals are Highest.
#    1. Califonia
#    2. New York
#    3. Texas
#
# -Wyoming have Lowest Number of deal

# %% [markdown]
# ### City

# %%
print("City with maximum Sales count: {} & with minimum Sales count: {}".format(EDA_df['City'].value_counts().idxmax(),EDA_df['City'].value_counts().idxmin()))
EDA_df['City'].value_counts().head(5)
# Out:
# City with maximum Sales count: New York City & with minimum Sales count: Kissimmee
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Name: City, dtype: int64

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Here is top 3 city where deals are Highest.
#    1. New York City
#    2. Los Angeles
#    3. Philadelphia

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(EDA_df['Sales'],color='red',label='Sales',shade=True,bw_adjust=25)
sns.kdeplot(EDA_df['Profit'],color='Blue',label='Profit',shade=True ,bw_adjust=25)
plt.xlim([-100,1000])
plt.legend()

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Profit is more than that of sale but there are some areas where profit could be increased.

# %%
#Based on the Category
sns.pairplot(EDA_df,hue='Category')

# %%
#Based on Region
sns.pairplot(EDA_df,hue='Region')

# %%
#Based on Segment
sns.pairplot(EDA_df,hue='Segment')

# %%
plt.figure(figsize=(8,8))
sns.heatmap(EDA_df.corr(),annot =True,cmap = 'rocket_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# -Sales and Profit are Moderately Correlated.
#
# -Discount and Profit are Negatively Correlated.
#
# -Quantity and Sales are less Moderately Correlated.

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(EDA_df['Category'],ax=axs[0][0])
sns.countplot(EDA_df['Segment'],ax=axs[0][1])
sns.countplot(EDA_df['Ship Mode'],ax=axs[1][0])
sns.countplot(EDA_df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)

plt.tight_layout()

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (10,10))
sns.distplot(EDA_df['Sales'], color = 'red',  ax = axs[0][0])
sns.distplot(EDA_df['Profit'], color = 'green',  ax = axs[0][1])
sns.distplot(EDA_df['Quantity'], color = 'orange',  ax = axs[1][0])
sns.distplot(EDA_df['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

x=EDA_df.groupby(by="Category")['Profit'].sum()
x.plot(kind='bar',ax=axs[0][0])

x=EDA_df.groupby(by="Segment")['Profit'].sum()
x.plot(kind='bar',ax=axs[0][1])

x=EDA_df.groupby(by="Ship Mode")['Profit'].sum()
x.plot(kind='bar',ax=axs[1][0])

x=EDA_df.groupby(by="Region")['Profit'].sum()
x.plot(kind='bar',ax=axs[1][1])

axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)

plt.tight_layout()

# %% [markdown]
# We can see that From the above graph that The profit earned from furniture is the lowest, and the profit earned from technology is highest, and the Office Supplies profit is somewhat similar to Technology, now lets focus on Furniture.

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Region',y='Profit', hue='Category',data=EDA_df)
plt.show()

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# We can see Above chart is the region wise distribution of the profit For Different Categories, we can also notice that the lowest profit of furniture is from central zone, then its the east zone, then the west zone and finally its the south zone

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Region',y='Profit', hue='Segment',data=EDA_df)
plt.show()

# %% [markdown]
# <font color='blue'>Analysis: </font>
#
# We can see Above chart is the region wise distribution of the profit For Different Segment, we can also notice that the lowest profit of Consumer is from central zone, then its the east zone, then the south zone and finally its the west zone
